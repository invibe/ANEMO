# %%
import Plot

# %%
Plot.Plot_classical_method.latency()
Plot.Plot_classical_method.anticipation()
Plot.Plot_classical_method.steady_state()
Plot.Plot_Model.SmoothPursuit.velocity_line()
Plot.Plot_Model.SmoothPursuit.velocity()
Plot.Plot_Model.SmoothPursuit.velocity_sigmo()
Plot.Plot_Model.SmoothPursuit.position()
Plot.Plot_Model.saccade()
