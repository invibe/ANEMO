# %% [markdown]
# # to_velocity_deg

# %% [raw]
# <br>

# %% [markdown]
# Transforms **the position of the eye in pixels** into **velocity (°/s)**

# %% [markdown]
# ## Test the parameters
#
# -----------------------------

# %% [raw]
# .. autofunction:: ANEMO.PreProcessing::PreProcessing.Trial.to_velocity_deg
#   :noindex:

# %% [raw]
# <br><br>

# %% [markdown]
# **example of code:** test the parameters of the function to ``the raw data position x of the eye in pixels``.

# %%
import ANEMO

PreProcessing = ANEMO.PreProcessing(dirpath='dataANEMO', sub='002')

#------------------------------------------------------------------------------
# Parameters:
#------------------------------------------------------------------------------
xname = 'xpr' # The raw position x of the eye in pixels
trial = 8 # Number of the trial to be transformed
expname = 'sub-002_task-aSPEM' # Name of the particular experience to be
                               # transformed
                               # or list(PreProcessing.data.keys())[0]
toxname = None # Name of the data to be saved
return_ = True # If True returns the value, else saves it in data

#------------------------------------------------------------------------------
# to apply the function:
#------------------------------------------------------------------------------
xpr_vdeg = PreProcessing.Trial.to_velocity_deg(xname,
                                               trial,
                                               expname,
                                               toxname,
                                               return_)

#------------------------------------------------------------------------------
# to retrieve the raw data:
#------------------------------------------------------------------------------
data_exp = PreProcessing.data[expname]
data = data_exp.Data
xpr = data[data.trial==trial][xname].values

#------------------------------------------------------------------------------
# Plot:
#------------------------------------------------------------------------------
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(10, 10/(1.681*2)))

axs[0].plot(xpr, 'k', alpha=.7)
axs[0].set_title('the position x of the eye in pixels: xpr')
axs[0].set_xlabel('time (ms)')
axs[0].set_ylabel('position of the eye (px)')

axs[1].plot(xpr_vdeg, 'k', alpha=.7)
axs[1].set_title('the velocity of the eye in °/s: xpr_vdeg')
axs[1].set_xlabel('time (ms)')
axs[1].set_ylabel('velocity of the eye (°/s)')

plt.tight_layout()
plt.show()

# %% [raw]
# <br><br>

# %% [markdown]
# **example of code:** test the parameters of the function to ``the raw data position y of the eye in pixels``.

# %%
import ANEMO

PreProcessing = ANEMO.PreProcessing(dirpath='dataANEMO', sub='002')

#------------------------------------------------------------------------------
# Parameters:
#------------------------------------------------------------------------------
xname = 'ypr' # The raw position y of the eye in pixels
trial = 8 # Number of the trial to be transformed
expname = 'sub-002_task-aSPEM' # Name of the particular experience to be
                               # transformed
                               # or list(PreProcessing.data.keys())[0]
toxname = None # Name of the data to be saved
return_ = True # If True returns the value, else saves it in data

#------------------------------------------------------------------------------
# to apply the function:
#------------------------------------------------------------------------------
ypr_vdeg = PreProcessing.Trial.to_velocity_deg(xname,
                                               trial,
                                               expname,
                                               toxname,
                                               return_)

#------------------------------------------------------------------------------
# to retrieve the raw data:
#------------------------------------------------------------------------------
data_exp = PreProcessing.data[expname]
data = data_exp.Data
ypr = data[data.trial==trial][xname].values

#---------------------------------------------------------------------------
# Plot:
#---------------------------------------------------------------------------
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(10, 10/(1.681*2)))

axs[0].plot(ypr, 'k', alpha=.7)
axs[0].set_title('the position y of the eye in pixels: ypr')
axs[0].set_xlabel('time (ms)')
axs[0].set_ylabel('position of the eye (px)')

axs[1].plot(ypr_vdeg, 'k', alpha=.7)
axs[1].set_title('the velocity of the eye in °/s: ypr_vdeg')
axs[1].set_xlabel('time (ms)')
axs[1].set_ylabel('velocity of the eye (°/s)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Run it on a data set
#
# ----------------------------

# %% [raw]
# .. autofunction:: ANEMO.PreProcessing::PreProcessing.Data.to_velocity_deg
#   :noindex:

# %% [raw]
# <br><br>

# %% [markdown]
# **example of code:** run this function on ``the full raw data of the x position of the eye in pixels``.

# %%
import ANEMO

PreProcessing = ANEMO.PreProcessing(dirpath='dataANEMO', sub='002')

#------------------------------------------------------------------------------
# Parameters:
#------------------------------------------------------------------------------
xname = 'xpr' # The raw position x of the eye in pixels
toxname= None # Name of the data to be saved,
              # If None toxname will take the value xname+'_deg'
expnames = 'sub-002_task-aSPEM' # Name of the particular experience to be
                                # transformed
                                # or list(PreProcessing.data.keys())[0] 
trials = list(range(1, 16)) # List of the trial to be transformed
recalculate = False # Allows you to indicate if you want to force the
                    # calculation on the trials already processed

#------------------------------------------------------------------------------
# to apply the function:
#------------------------------------------------------------------------------
PreProcessing.Data.to_velocity_deg(xname,
                                   toxname,
                                   expnames,
                                   trials,
                                   recalculate)
# Out:
# calculates xpr_vdeg from the file sub-002_task-aSPEM... finished

# %% [raw]
# <br><br>

# %% [markdown]
# **example of code:** run this function on ``the full raw data of the y position of the eye in pixels``.

# %%
import ANEMO

PreProcessing = ANEMO.PreProcessing(dirpath='dataANEMO', sub='002')

#------------------------------------------------------------------------------
# Parameters:
#------------------------------------------------------------------------------
xname = 'ypr' # The raw position y of the eye in pixels
toxname= None # Name of the data to be saved,
              # If None toxname will take the value xname+'_deg'
expnames = 'sub-002_task-aSPEM' # Name of the particular experience to be
                                # transformed
                                # or list(PreProcessing.data.keys())[0] 
trials = list(range(1, 16)) # List of the trial to be transformed
recalculate = False # Allows you to indicate if you want to force the
                    # calculation on the trials already processed

#------------------------------------------------------------------------------
# to apply the function:
#------------------------------------------------------------------------------
PreProcessing.Data.to_velocity_deg(xname,
                                   toxname,
                                   expnames,
                                   trials,
                                   recalculate)
# Out:
# calculates ypr_vdeg from the file sub-002_task-aSPEM... finished
