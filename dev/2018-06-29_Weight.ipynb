# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # extracting data and doing the fit on velocity

# %%
from ANEMO.edfreader import read_edf

import pickle
with open('../demo/result/param_Fit_AM.pkl', 'rb') as fichier:
    param = pickle.load(fichier, encoding='latin1')
with open('../demo/data/enregistrement_AM_2017-10-23_100057.pkl', 'rb') as fichier:
    file_exp = pickle.load(fichier, encoding='latin1')

datafile = '../demo/data/enregistrement_AM_2017-10-23_100057.asc'
data = read_edf(datafile, 'TRIALID')

# %%
def deco(axs) :
    axs.axvspan(arg.StimulusOn-start, arg.StimulusOf-start, color='k', alpha=0.2)
    axs.axvspan(arg.StimulusOf-start, arg.TargetOn-start, color='r', alpha=0.2)
    axs.axvspan(arg.TargetOn-start, arg.TargetOff-start, color='k', alpha=0.15)
    for s in range(len(arg.saccades)) :
        axs.axvspan(arg.saccades[s][0]-start, arg.saccades[s][1]-start, color='k', alpha=0.2)

# %%
def regress(ax, p, data, minx, miny, maxx, maxy, t_label=12) :
    from scipy import stats
    slope, intercept, r_, p_value, std_err = stats.linregress(p, data)
    x_test = np.linspace(np.min(p), np.max(p), 100)
    fitLine = slope * x_test + intercept
    ax.plot(x_test, fitLine, c='k', linewidth=2)
    ax.text(maxx-((maxx-minx)/16.180),miny+((maxy-miny)/10), 'r = %0.3f'%(r_), fontsize=t_label/1.2, ha='right')

    return ax

# %%
def position(x, bino, start_anti, a_anti, latency, tau, maxi, trial_data, px_per_deg, nan=False, avant=5, apres=10):
    saccades = data[trial_data]['events']['Esac'] #[starttime, endtime, duration, startx, starty, endx, endy]
    data_x = data[trial_data]['x']
    
    #gradient_deg = gradient_x * 1/px_per_deg * 1000 # gradient en deg/sec
    ms = 1000
    a_anti = (a_anti/ms) # pour passer de sec à ms
    maxi = maxi /ms
    
    speed = ANEMO.fct_velocity(x, bino, start_anti, a_anti, latency, tau, maxi)
    pos = np.cumsum(speed)

    if nan == True :
        avant, apres =  5, 10 #15
        for sacc in saccades :
            if sacc[0]-t_0 < len(pos) :
                if sacc[0]-t_0 > int(latency) :
                    if int(sacc[1]-t_0)+apres <= len(pos) :
                        pos[int(sacc[0]-t_0)-avant:int(sacc[1]-t_0)+apres] = np.nan 
                        pos[int(sacc[1]-t_0)+apres:] += ((data_x[int(sacc[1]-t_0)+apres]-data_x[int(sacc[0]-t_0)-avant-1])/px_per_deg) - np.mean(speed[int(sacc[0]-t_0):int(sacc[1]-t_0)]) * sacc[2]

                    else :
                        pos[int(sacc[0]-t_0)-avant:] = np.nan
 
    return pos

# %% [markdown]
# # doing the fit

# %%
def Fit_position(position_x, trackertime, bino, trial_data, TargetOn, StimulusOf, saccades,
                 px_per_deg, param_fit=None, sup=False, time_sup=-280, step=2, nan=True,
                 fit_weight=True, weight=1) :

    from lmfit import  Model, Parameters

    t_0 = trackertime[0]

    if param_fit is None :
        param_fit={'tau':[15.,13.,80.], 'maxi':[15.,1.,40], 'a_anti':[0.,-40.,40.],
                   'latency':[TargetOn-t_0+100,TargetOn-t_0+75,'STOP'],
                   'start_anti':[TargetOn-t_0-100, StimulusOf-t_0-200, TargetOn-t_0+75]}

    if param_fit['latency'][2]=='STOP' :
        stop_latency = []
        for s in range(len(saccades)) :
            if (saccades[s][0]-t_0) >= (TargetOn-t_0+100) :
                stop_latency.append((saccades[s][0]-t_0))
        if stop_latency==[] :
            stop_latency.append(len(trackertime))
        stop = stop_latency[0]
    else :
        stop = param_fit['latency'][2]


    if sup==True :
        position_x = position_x[:time_sup]
        trackertime = trackertime[:time_sup]
    
    
    model = Model(position)

    params = Parameters()

    if step == 1 :
        vary = True
    elif step == 2 :
        vary = False

    params.add('nan', value=nan, vary=False)
    params.add('bino', value=bino, vary=False)
    params.add('trial_data', value=trial_data, vary=False)
    params.add('avant', value=5, vary=False)
    params.add('apres', value=10, vary=False)
    params.add('px_per_deg', value=px_per_deg, vary=False)

    
    params.add('maxi', value=param_fit['maxi'][0], min=param_fit['maxi'][1], max=param_fit['maxi'][2])
    params.add('latency', value=param_fit['latency'][0], min=param_fit['latency'][1], max=stop)
    params.add('tau', value=param_fit['tau'][0], min=param_fit['tau'][1], max=param_fit['tau'][2], vary=vary)
    params.add('start_anti', value=param_fit['start_anti'][0], min=param_fit['start_anti'][1], max=param_fit['start_anti'][2], vary=vary)
    params.add('a_anti', value=param_fit['a_anti'][0], min=param_fit['a_anti'][1], max=param_fit['a_anti'][2], vary=vary)

    if fit_weight is True :
        a = np.array(range(len(trackertime)))
        a[:time_sup]= weight
        a[time_sup:] = 0
    else :
        a = None
    
    if step == 1 :
        result_deg = model.fit(position_x, params, x=np.arange(len(trackertime)), nan_policy='omit')

    elif step == 2 :
        out = model.fit(position_x, params, x=np.arange(len(trackertime)), weight=a, nan_policy='omit')
        out.params['tau'].set(vary=True)
        out.params['start_anti'].set(vary=True)
        out.params['a_anti'].set(vary=True)

        result_deg = model.fit(position_x, out.params, x=np.arange(len(trackertime)), weight=a, method='nelder', nan_policy='omit')
                                
    return result_deg

# %%
from ANEMO import ANEMO

block, trial = 0, 14
arg = ANEMO.arg(data, file_exp, trial, block)


trial_data = trial + arg.N_trials*block
time, t_0 = arg.trackertime, arg.t_0
start, start1 = arg.TargetOn, arg.TargetOn-t_0

data_1 = (arg.data_x-(arg.data_x[arg.StimulusOf-t_0])) / arg.px_per_deg

kwarg_0 = {'trial_data' : trial_data, 'px_per_deg' : arg.px_per_deg, 'nan' : True}
kwarg_1 = {'trackertime' : time, 'bino' : arg.bino,
             'TargetOn' : arg.TargetOn, 'StimulusOf' : arg.StimulusOf,
             'saccades' : arg.saccades, 'step' : 2, **kwarg_0}

# %%
def fct(sup=True, fit_weight=False, weight=1) :
    c = Fit_position(data_1, sup=sup, fit_weight=fit_weight, weight=weight, **kwarg_1)
    d = position(np.arange(len(time)), arg.bino, c.values['start_anti'], c.values['a_anti'],
                 c.values['latency'], c.values['tau'], c.values['maxi'],  **kwarg_0)



    popo = position(np.arange(len(time)), arg.bino, param['start_anti'][block][trial]+start1,
                    param['a_anti'][block][trial], param['latency'][block][trial]+start1,
                    param['tau'][block][trial], param['maxi'][block][trial], **kwarg_0)


    e = Fit_position(popo, sup=sup, fit_weight=fit_weight, weight=weight, **kwarg_1)
    f = position(np.arange(len(time)), arg.bino, e.values['start_anti'], e.values['a_anti'],
                 e.values['latency'], e.values['tau'], e.values['maxi'], **kwarg_0)


    print('sup %s, fit_weight %s, weight %s'%(sup, fit_weight, weight),
          '\nstart_anti : %0.3f, c -> %0.3f, e -> %0.3f'%(param['start_anti'][block][trial], c.values['start_anti']-start1, e.values['start_anti']-start1), 
          '\na_anti : %0.3f, c -> %0.3f, e -> %0.3f'%(param['a_anti'][block][trial], c.values['a_anti'], e.values['a_anti']), 
          '\nlatency : %0.3f, c -> %0.3f, e -> %0.3f'%(param['latency'][block][trial], c.values['latency']-start1, e.values['latency']-start1),
          '\ntau : %0.3f, c -> %0.3f, e -> %0.3f'%(param['tau'][block][trial], c.values['tau'], e.values['tau']),
          '\nmaxi : %0.3f, c -> %0.3f, e -> %0.3f\n\n'%(param['maxi'][block][trial], c.values['maxi'], e.values['maxi']))
    
    fig_width= 15
    fig, axs = plt.subplots(1, 1, figsize=(fig_width, (fig_width/2)/1.6180))

    deco(axs)
    axs.set_title('sup %s, fit_weight %s, weight %s'%(sup, fit_weight, weight))
    axs.plot(time-start, data_1, color='k', alpha=0.4, label='raw position')
    axs.plot(time-start, d, '--k', label='Fit on position')
    axs.plot(time-start, popo, color='r', label='fit on speed')
    axs.plot(time-start, f, '--r', label='Fit on fit on speed -> synthetic data')
    axs.legend();

# %%
fct(sup=True, fit_weight=True, weight=1000)
fct(sup=True, fit_weight=False)
fct(sup=False, fit_weight=True, weight=1000)
fct(sup=False, fit_weight=False)
# Out:
# /home/drone/.local/lib/python3.5/site-packages/lmfit/model.py:821: UserWarning: The keyword argument weight does notmatch any arguments of the model function.It will be ignored.
#   "It will be ignored.", UserWarning)
# sup True, fit_weight True, weight 1000
# start_anti : 58.296, c -> 5.001, e -> 24.019
# a_anti : 20.075, c -> 3.279, e -> 8.225
# latency : 179.000, c -> 189.000, e -> 152.000
# tau : 53.519, c -> 31.962, e -> 13.003
# maxi : 13.567, c -> 15.204, e -> 14.759
#
#
# sup True, fit_weight False, weight 1
# start_anti : 58.296, c -> 5.001, e -> 24.019
# a_anti : 20.075, c -> 3.279, e -> 8.225
# latency : 179.000, c -> 189.000, e -> 152.000
# tau : 53.519, c -> 31.962, e -> 13.003
# maxi : 13.567, c -> 15.204, e -> 14.759
#
#
# sup False, fit_weight True, weight 1000
# start_anti : 58.296, c -> 35.035, e -> -30.760
# a_anti : 20.075, c -> 7.130, e -> 2.938
# latency : 179.000, c -> 180.000, e -> 151.000
# tau : 53.519, c -> 13.319, e -> 13.216
# maxi : 13.567, c -> 13.465, e -> 15.363
#
#
# sup False, fit_weight False, weight 1
# start_anti : 58.296, c -> 35.035, e -> -30.760
# a_anti : 20.075, c -> 7.130, e -> 2.938
# latency : 179.000, c -> 180.000, e -> 151.000
# tau : 53.519, c -> 13.319, e -> 13.216
# maxi : 13.567, c -> 13.465, e -> 15.363

# %%
# il semble qu'il n'y a pas de différence entre le fit avec ou sans weight
